# %% [markdown]
# ### GAN Project
#
#
# #### To do list:
#
#
#
#
# *   Build a model that can generate new images from noise
#
#
# > with potential developments:
#
#
# > 0. build a CNN by your self
#
# > 1. Change the discriminator into a ImageNet (which is now proved challenging due to memory issue)
#
# > 2. Change the discriminator into an ensembled model (e.g. SIFT + CNN)
#
# >
#
#
#
#
#
#
# *   Build a model that can generate new images from old images
#
# > with methods:
#
# > 1. Input size = output size (do remember to make sure same diagnose is made for the training data  i.e.: one model for one disease)
#
# > 2. Blur the input image so that the input size is smaller than output size
#
# >
#
#
#
# *   The above are done by 2d networks, we should try 3d networks later
#
#
# *   Canny Edge!

# %% [markdown]
# #### Some other things to do:
#
# 1. Study 3d conv: (maybe from youtube first?) e.g. https://www.youtube.com/results?search_query=3d+convolutional+neural+network+tutorial+
#
# 2. Study traditional models (from Udemy)
#
# 3. Do build your own model so that the we can control the training

# %% [markdown]
# #### Today to do list:
#
# #### 1. Build own program: so that we can:
#
#
#
# > 1. initialization by our selves
#
# > 2. control the training propagation i.e. train what we want to train, freeze the layers when necessary
#
# > 3. ensemble the discriminator, and learn to combine two models

# %% [markdown]
# # Log

# %% [markdown]
# ### Mar 20
#
# 0. Built the data preprocessing model, which can resize the image to any shape (e.g. (50, 50)), meanwhile, we can change the image array batch size, eg output and save np array of shape (10000, 50, 50)
#
# 1. Attempted "GAN First Attempt Lighter 50sqr.ipynb", but the generated image is quite blurred, which is caused by the weak dicriminator (seems the accuracy of the D is high, so it may be G issue??? )
#
# 2. Attempted Inception V3 as the discriminator, high possibility to meet compatibility issue, and must use input size >= (139, 139)
#
# 3. Attempted G_Dense_random + D_CNN, generator killed
#
# 4. Attempted D_Dense_e15000 + D_CNN, generator killed
#
# 5. We can try stronger generator: 1. from bigger random 1d array, 2. from (50,50) random 2d, 3. from blurred X-Chest
